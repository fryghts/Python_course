# %%
import pandas as pd

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/jorisvandenbossche/pandas-tutorial/master/data/titanic.csv', index_col="PassengerId")

# %%
df = pd.read_csv('titanic.csv', index_col="PassengerId")

# %%
df

# %% [markdown]
# **Методы `head` и `tail` помогут посмотреть на начало и конец датафрейма**

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# **Обращение к столбцам происходит по их именам**

# %%
df.Name

# %% [markdown]
# **С помощью `loc` и `iloc` можно обращаться к строкам по их именам или индексам соответственно**

# %%
df.iloc[0, 2:5]

# %% [markdown]
# **Каждый столбец является `pd.Series`, при помощи сравнений можно получить маску истинности**

# %%
df.Age.isin([22,33])

# %% [markdown]
# **Для примера отберем пассажиров, которые сели в Cherbourg (Embarked=C) и заплатили более 200 у.е. за билет (fare > 200).**

# %%
df2 = df.loc[(df.City == 'C') & (df.Fare > 200)]

# %% [markdown]
# **C помощью `sort_values` можно отсортировать этих людей по убыванию платы за билет.**

# %%
df2.sort_values('Fare', ascending = False)

# %%
df

# %% [markdown]
# **Отрисовка графиков**
#
# `line`, `bar`, `barh`, `hist`, `box`, `kde`, `density`, `area`, `pie`, `scatter`, `hexbin`

# %%
df['Age_category'].value_counts().plot(kind='bar')

# %%
df['Age'].hist(bins = 20)

# %% [markdown]
# **0. С помощью `str` можно применять строковые методы к строковым столбцам. Найдите самое популярное имя среди пассажиров Титаника мужского пола**

# %% [markdown]
# **1. Сколько мужчин / женщин находилось на борту?**

# %% [markdown]
# **2. Выведите распределение переменной `Pclass` (социально-экономический статус) и это же распределение, только для мужчин / женщин по отдельности. Сколько было мужчин 2-го класса?**

# %% [markdown]
# **3. Каковы медиана и стандартное отклонение платежей (`Fare`)?**

# %% [markdown]
# **4. Правда ли, что люди моложе 30 лет выживали чаще, чем люди старше 55 лет? Каковы доли выживших в обеих группах?**

# %% [markdown]
# **5. Правда ли, что женщины выживали чаще мужчин? Каковы доли выживших в обеих группах?**

# %% [markdown]
# **6. Как отличается средний возраст мужчин / женщин в зависимости от класса обслуживания?**
